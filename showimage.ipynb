# %%
from math import ceil
import os
import logging
from pathlib import Path
import json
from PIL import Image
import base64
from io import BytesIO
from dataclasses import dataclass
import tqdm
import argparse
import os
from tqdm import tqdm
import lmdb
import json
import pickle

# %%
base64_path = "/data1/zhn/macdata/code/github/python/modelData/datasets/MUGE/train_imgs.tsv"

# %%
with open(base64_path, "r", encoding="utf-8") as fin_imgs:
     
     for line in tqdm(fin_imgs):
          line = line.strip()
          image_id, b64 = line.split("\t")
          # print("image_id", image_id)
          if image_id == "97905":
               print("image_id", image_id)
               image_data = base64.b64decode(b64)
               image = Image.open(BytesIO(image_data))
               image.show()
# Out:
# 0it [00:00, ?it/s]
# 127607it [01:52, 1149.28it/s]
# image_id 97905
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FC8761634F0>
# 129380it [01:53, 1139.86it/s]
